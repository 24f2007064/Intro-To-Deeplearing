# %%
# Question:
#
# Given the following dataset containing CGPA and placement status:
#
# CGPA    Placed
# 8.11      1
# 8.90      1
# 7.00      0
# 6.56      1
# 4.56      0
#
# Build a Logistic Regression model from scratch using PyTorch.
#
# Initialize:
# w = 1
# b = 0
#
# Train the model using:
# 1. Forward Pass
# 2. Sigmoid Activation
# 3. Binary Cross Entropy Loss
# 4. Autograd (Backward Pass)
# 5. Gradient Descent
#
# Run the training process for multiple epochs and observe how
# the values of w and b change, the loss decreases, and the
# predictions become closer to the actual placement labels.
