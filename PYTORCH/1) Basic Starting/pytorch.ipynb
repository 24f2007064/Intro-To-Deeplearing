# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
# !nvidia-smi
# Out:
# Tue Jun 16 07:15:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
torch.cuda.is_available()
# Out:
# True

# %%
if torch.cuda.is_available():
    print(f"cureent cuda device {torch.cuda.current_device()}")
    print(f"device name {torch.cuda.get_device_name()}")
    print(f"Device capabilities: CUDA {torch.cuda.get_device_capability()}")
    print(f"Device properties: {torch.cuda.get_device_properties()}")
# Out:
# cureent cuda device 0
# device name Tesla T4
# Device capabilities: CUDA (7, 5)
# Device properties: _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=14912MB, multi_processor_count=40, uuid=45a2030e-0ae0-0ca4-10e1-5123d70b1304, pci_bus_id=0, pci_device_id=4, pci_domain_id=0, L2_cache_size=4MB)
