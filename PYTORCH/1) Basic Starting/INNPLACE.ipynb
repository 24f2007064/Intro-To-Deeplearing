# %%
import torch

# %%
d = torch.randint(size = (3,3), low = 1, high = 13)
e = torch.randint(size = (3,3), low = 1, high = 13)

d,e
# Out:
# (tensor([[ 8,  9, 11],
#          [ 4,  3,  1],
#          [10, 11,  9]]),
#  tensor([[ 4, 10,  3],
#          [10,  1, 11],
#          [ 6,  1,  5]]))

# %% [markdown]
# #### FOr in place operation we just have to use '_'
# #### for example--> d.add_(e)
# ### veraible.operations_()

# %%
d.add(e)
# Out:
# tensor([[12, 19, 14],
#         [14,  4, 12],
#         [16, 12, 14]])

# %%
d
# Out:
# tensor([[ 8,  9, 11],
#         [ 4,  3,  1],
#         [10, 11,  9]])

# %%
d.add_(e)
# Out:
# tensor([[12, 19, 14],
#         [14,  4, 12],
#         [16, 12, 14]])

# %%
d
# Out:
# tensor([[12, 19, 14],
#         [14,  4, 12],
#         [16, 12, 14]])
