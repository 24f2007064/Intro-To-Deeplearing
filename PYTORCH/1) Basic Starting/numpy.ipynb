# %%
import torch
import numpy

# %%
a = torch.tensor([1,2,3])
type(a)
# Out:
# torch.Tensor

# %%
b = a.numpy()
type(b)
# Out:
# numpy.ndarray

# %%
c = torch.from_numpy(b)
type(c)
# Out:
# torch.Tensor
